# %% [markdown]
# ### Add tuning

# %% [markdown]
# # Synthetic dataset creation
#
# In this notebook I create a synthetic dataset to test the proposed bandit algorithm and compare it to benchmarks.
# Synthetic dataset will have following features:
# - 10,000 time points
# - At each time $t$ the environment generates a context vector $x_t$ of dimension 6. Each feature $x_t^{(i)}$ is **categorical**, and lies in range(1,feature_size). This is needed for the `state_extract` function in SimOOS to correctly number all the states.
# - Each context vector $x_t$ is associated with a cost vector $c_t$. Cost of each feature $c_t^{i}$ follows a Gaussian distribution with fixed standard deviation and **piecewise-constant** mean lying in range $[0; 0.04]$. Change-points of costs are different from change points of rewards.
# - A fixed (for all $t$) set $\mathcal{A}$ of 5 arms are available for the algorithm to choose from.
# - Rewards associated with each arm and context follow a Bernoulli distribution, parametrized by $p = \sigma(\bar{x_t}^T\theta_{t,a})$. Here $\bar{x_t}$ is not context observed at time t, but rather it is expected context inside one stationarity interval.  Also $\sigma()$ is the sigmoid function and $\theta_{t,a}$ is the ground truth bandit parameter (not disclosed to the algorithm) associated with each arm $a_i$ at time $t$. Bandit parameter satisfies condition $\lVert\theta_{t,a}\rVert_2 \le 1$.  For each arm $a_i$, parameter $\theta_{t,a}$ is piecewise-constant and thus the corresponding **generating process of rewards is piecewise-stationary** with change points every 2000 steps.
# This method of generating rewards from contexts follows [1] and [2], but instead of Gaussian reward with mean $x_t^T\theta_{t,a}$ the reward is Bernoulli with parameter $\sigma(\bar{x_t}^T\theta_{t,a})$
#
# [1] Learning Contextual Bandits in a Non-stationary Environment, Wu et al.
#
# [2] Contextual-Bandit Based Personalized Recommendation with Time-Varying User Interests, Xu et al.

# %%
import os
os.chdir('../..')
os.getcwd()
# Out:
# '/Users/sbokupripeku/git/work/examples/costly_nonstationary_bandits'

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import time
import math
import pickle

import costs
from plotting.costs import plot_costs

# %%
# Set random seeds for reproducibility
np.random.seed(42)

# %% [markdown]
# #### Setting important constants

# %%
TIME_POINTS = 10000
NUM_FEATURES = 4
N_ARMS = 5

# %% [markdown]
# ## Loading the synthetic dataset

# %%
with open('dataset/synthetic/synthetic_data.pickle', 'rb') as f:
    data = pickle.load(f)

# %%
contexts, rewards, costs_vector = data

# %% [markdown]
# ## Testing algorithms on synthetic data

# %%
# %load_ext autoreload
# %autoreload 2

import algorithms
import evaluation
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
NUM_OF_TRIALS = 10000
TUNING_NUM_TRIALS = 2500

# %% [markdown]
# ### Random policy

# %% [markdown]
# #### Evaluation

# %%
p_random = algorithms.RandomPolicy()
gain_random = evaluation.evaluate_on_synthetic_data(
    p_random,
    contexts,
    rewards,
    costs_vector,
    stop_after=NUM_OF_TRIALS,
)
# Out:
# Random policy
# Total gain: 12108.0
# 	Total reward: 12108.0
# 	Total cost: 0
# Execution time: 0.1s

# %% [markdown]
# ### $\epsilon$-greedy

# %% [markdown]
# #### Tuning

# %%
egreedy_gains = {}

for eps in [0.001, 0.005, 0.01, 0.05, 0.08, 0.1, 0.2, 0.3]:
    egreedy = algorithms.EpsilonGreedy(epsilon=eps, n_arms=rewards.shape[1])

    gain_egreedy = evaluation.evaluate_on_synthetic_data(
        egreedy,
        contexts,
        rewards,
        costs_vector,
        stop_after=TUNING_NUM_TRIALS,
    )
    egreedy_gains[eps] = gain_egreedy
# Out:
# E-greedy(epsilon=0.001)
# Total gain: 2712.0
# 	Total reward: 2712.0
# 	Total cost: 0
# Execution time: 0.0s
#
# E-greedy(epsilon=0.005)
# Total gain: 2056.0
# 	Total reward: 2056.0
# 	Total cost: 0
# Execution time: 0.0s
#
# E-greedy(epsilon=0.01)
# Total gain: 2864.0
# 	Total reward: 2864.0
# 	Total cost: 0
# Execution time: 0.0s
#
# E-greedy(epsilon=0.05)
# Total gain: 4452.0
# 	Total reward: 4452.0
# 	Total cost: 0
# Execution time: 0.0s
#
# E-greedy(epsilon=0.08)
# Total gain: 4184.0
# 	Total reward: 4184.0
# 	Total cost: 0
# Execution time: 0.0s
#
# E-greedy(epsilon=0.1)
# Total gain: 4704.0
# 	Total reward: 4704.0
# 	Total cost: 0
# Execution time: 0.0s
#
# E-greedy(epsilon=0.2)
# Total gain: 3512.0
# 	Total reward: 3512.0
# 	Total cost: 0
# Execution time: 0.0s
#
# E-greedy(epsilon=0.3)
# Total gain: 4132.0
# 	Total reward: 4132.0
# 	Total cost: 0
# Execution time: 0.0s

# %%
last_gains = {k:v[-1] for k,v in egreedy_gains.items()}
best_eps = sorted(last_gains.items(), key=lambda x: x[1])[-1][0]

# %%
best_eps
# Out:
# 0.1

# %%
del egreedy_gains

# %% [markdown]
# #### Evaluation

# %%
egreedy = algorithms.EpsilonGreedy(epsilon=best_eps, n_arms=rewards.shape[1])

gain_egreedy = evaluation.evaluate_on_synthetic_data(
    egreedy,
    contexts,
    rewards,
    costs_vector,
    stop_after=NUM_OF_TRIALS,
)
# Out:
# E-greedy(epsilon=0.1)
# Total gain: 17496.0
# 	Total reward: 17496.0
# 	Total cost: 0
# Execution time: 0.1s

# %% [markdown]
# ### UCB1

# %% [markdown]
# #### Tuning

# %%
ucb_gains = {}

for alpha in [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5,
                0.9, 1.0, 2.0, 5.0, 8.0, 10.0, 20.0, 30.0, 40.0
             ]:
    ucb_alg = algorithms.UCB1(
        n_trials=TUNING_NUM_TRIALS,
        n_arms=rewards.shape[1],
        alpha=alpha,
    )

    gain_ucb = evaluation.evaluate_on_synthetic_data(
        ucb_alg,
        contexts,
        rewards,
        costs_vector,
        stop_after=TUNING_NUM_TRIALS,
    )
    ucb_gains[alpha] = gain_ucb
# Out:
# UCB1 (α=0.01)
# Total gain: 1808.0
# 	Total reward: 1808.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.05)
# Total gain: 1956.0
# 	Total reward: 1956.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.1)
# Total gain: 2472.0
# 	Total reward: 2472.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.15)
# Total gain: 3148.0
# 	Total reward: 3148.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.2)
# Total gain: 3860.0
# 	Total reward: 3860.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.25)
# Total gain: 1948.0
# 	Total reward: 1948.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.3)
# Total gain: 4684.0
# 	Total reward: 4684.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.35)
# Total gain: 4944.0
# 	Total reward: 4944.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.4)
# Total gain: 4436.0
# 	Total reward: 4436.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.45)
# Total gain: 4652.0
# 	Total reward: 4652.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.5)
# Total gain: 4820.0
# 	Total reward: 4820.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=0.9)
# Total gain: 3244.0
# 	Total reward: 3244.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=1.0)
# Total gain: 4604.0
# 	Total reward: 4604.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=2.0)
# Total gain: 4784.0
# 	Total reward: 4784.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=5.0)
# Total gain: 3476.0
# 	Total reward: 3476.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=8.0)
# Total gain: 3432.0
# 	Total reward: 3432.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=10.0)
# Total gain: 4188.0
# 	Total reward: 4188.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=20.0)
# Total gain: 4284.0
# 	Total reward: 4284.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=30.0)
# Total gain: 4860.0
# 	Total reward: 4860.0
# 	Total cost: 0
# Execution time: 0.0s
#
# UCB1 (α=40.0)
# Total gain: 4900.0
# 	Total reward: 4900.0
# 	Total cost: 0
# Execution time: 0.0s

# %%
last_gains = {k:v[-1] for k,v in ucb_gains.items()}
best_alpha_ucb = sorted(last_gains.items(), key=lambda x: x[1])[-1][0]

# %%
best_alpha_ucb
# Out:
# 0.35

# %%
del ucb_gains

# %% [markdown]
# #### Evaluation

# %%
ucb_alg = algorithms.UCB1(
        n_trials=NUM_OF_TRIALS,
        n_arms=rewards.shape[1],
        alpha=best_alpha_ucb,
    )

gain_ucb = evaluation.evaluate_on_synthetic_data(
    ucb_alg,
    contexts,
    rewards,
    costs_vector,
    stop_after=NUM_OF_TRIALS,
)
# Out:
# UCB1 (α=0.35)
# Total gain: 16356.0
# 	Total reward: 16356.0
# 	Total cost: 0
# Execution time: 0.1s

# %% [markdown]
# ### LinUCB

# %% [markdown]
# #### Tuning

# %%
linucb_gains = {}

for alpha in [0.01, 0.05, 0.1, 0.2, 0.3, 0.35, 0.4, 0.5, 1.0, 5.0, 8.0, 20.0, 30.0, 40.0, 50.0, 60.0
             ]:
    linucb = algorithms.LinUCB(
        n_trials=TUNING_NUM_TRIALS,
        context_dimension=contexts.shape[1],
        n_arms=rewards.shape[1],
        alpha=alpha,
    )
    gain_linucb = evaluation.evaluate_on_synthetic_data(
        linucb,
        contexts,
        rewards,
        costs_vector,
        stop_after=TUNING_NUM_TRIALS,
    )
    linucb_gains[alpha] = gain_linucb
# Out:
# LinUCB (alpha=0.01)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=0.05)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=0.1)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# LinUCB (alpha=0.2)
# Total gain: 648.9447265113465
# 	Total reward: 3476.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# LinUCB (alpha=0.3)
# Total gain: 952.9447265113458
# 	Total reward: 3780.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=0.35)
# Total gain: 740.9447265113465
# 	Total reward: 3568.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=0.4)
# Total gain: 696.9447265113467
# 	Total reward: 3524.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=0.5)
# Total gain: 424.94472651134635
# 	Total reward: 3252.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=1.0)
# Total gain: 412.9447265113458
# 	Total reward: 3240.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# LinUCB (alpha=5.0)
# Total gain: 2016.9447265113456
# 	Total reward: 4844.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=8.0)
# Total gain: 2024.9447265113456
# 	Total reward: 4852.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=20.0)
# Total gain: 2388.944726511347
# 	Total reward: 5216.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=30.0)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# LinUCB (alpha=40.0)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# LinUCB (alpha=50.0)
# Total gain: 1940.944726511348
# 	Total reward: 4768.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# LinUCB (alpha=60.0)
# Total gain: 1712.9447265113472
# 	Total reward: 4540.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s

# %%
last_gains = {k:v[-1] for k,v in linucb_gains.items()}
best_alpha_linucb = sorted(last_gains.items(), key=lambda x: x[1])[-1][0]

# %%
best_alpha_linucb
# Out:
# 20.0

# %%
del linucb_gains

# %% [markdown]
# #### Evaluation

# %%
linucb = algorithms.LinUCB(
    n_trials=NUM_OF_TRIALS,
    context_dimension=contexts.shape[1],
    n_arms=rewards.shape[1],
    alpha=best_alpha_linucb,
)
gain_linucb = evaluation.evaluate_on_synthetic_data(
    linucb,
    contexts,
    rewards,
    costs_vector,
    stop_after=NUM_OF_TRIALS,
)
# Out:
# LinUCB (alpha=20.0)
# Total gain: 11913.463821340843
# 	Total reward: 24600.0
# 	Total cost: 12686.536178659138
# Execution time: 0.6s

# %% [markdown]
# ### PS-LinUCB

# %% [markdown]
# #### Tuning

# %%
ps_linucb_gains = {}

for alpha in [0.01, 0.05, 0.1, 0.2, 0.3, 0.35, 0.4, 0.5, 1.0, 5.0, 8.0, 20.0, 30.0, 40.0]:
    for omega in [100, 150,  250, 500, 750, 1000, 1500, 2000]:
        for delta in [0.001, 0.003, 0.004, 0.005, 0.006, 0.007, 0.01, 0.03, 0.05, 0.1, 0.15, 0.2, ]:
            ps_linucb = algorithms.PSLinUCB(
                n_trials=TUNING_NUM_TRIALS,
                context_dimension=contexts.shape[1],
                n_arms=rewards.shape[1],
                alpha=alpha,
                omega=omega,
                delta=delta,
            )


            gain_pslinucb = evaluation.evaluate_on_synthetic_data(
                ps_linucb,
                contexts,
                rewards,
                costs_vector,
                stop_after=TUNING_NUM_TRIALS,
            )
            
            ps_linucb_gains[(alpha, omega, delta)] = gain_pslinucb
# Out:
# PSLinUCB (alpha=0.01, omega=100, delta=0.001)
# Total gain: 1856.9447265113467
# 	Total reward: 4684.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.003)
# Total gain: 1856.9447265113467
# 	Total reward: 4684.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.004)
# Total gain: 1856.9447265113467
# 	Total reward: 4684.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.005)
# Total gain: 1856.9447265113467
# 	Total reward: 4684.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.006)
# Total gain: 1856.9447265113467
# 	Total reward: 4684.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.007)
# Total gain: 1856.9447265113467
# 	Total reward: 4684.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.01)
# Total gain: 1856.9447265113467
# 	Total reward: 4684.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.03)
# Total gain: 1856.9447265113467
# 	Total reward: 4684.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.05)
# Total gain: 1856.9447265113467
# 	Total reward: 4684.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.1)
# Total gain: 2752.944726511348
# 	Total reward: 5580.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.15)
# Total gain: 2108.944726511347
# 	Total reward: 4936.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=100, delta=0.2)
# Total gain: 1912.9447265113465
# 	Total reward: 4740.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.001)
# Total gain: 1204.9447265113474
# 	Total reward: 4032.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.003)
# Total gain: 1204.9447265113474
# 	Total reward: 4032.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.004)
# Total gain: 1204.9447265113474
# 	Total reward: 4032.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.005)
# Total gain: 1204.9447265113474
# 	Total reward: 4032.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.006)
# Total gain: 1204.9447265113474
# 	Total reward: 4032.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.007)
# Total gain: 1204.9447265113474
# 	Total reward: 4032.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.01)
# Total gain: 1204.9447265113474
# 	Total reward: 4032.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.03)
# Total gain: 1204.9447265113474
# 	Total reward: 4032.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.05)
# Total gain: 1204.9447265113474
# 	Total reward: 4032.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.1)
# Total gain: 1392.9447265113479
# 	Total reward: 4220.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.15)
# Total gain: 1536.9447265113477
# 	Total reward: 4364.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=150, delta=0.2)
# Total gain: 1548.9447265113479
# 	Total reward: 4376.0
# 	Total cost: 2827.055273488652
# Execution time: 0.3s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.001)
# Total gain: -667.055273488653
# 	Total reward: 2160.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.003)
# Total gain: -667.055273488653
# 	Total reward: 2160.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.004)
# Total gain: -667.055273488653
# 	Total reward: 2160.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.005)
# Total gain: -667.055273488653
# 	Total reward: 2160.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.006)
# Total gain: -667.055273488653
# 	Total reward: 2160.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.007)
# Total gain: -667.055273488653
# 	Total reward: 2160.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.01)
# Total gain: -667.055273488653
# 	Total reward: 2160.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.03)
# Total gain: -667.055273488653
# 	Total reward: 2160.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.05)
# Total gain: 516.9447265113479
# 	Total reward: 3344.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.1)
# Total gain: 516.9447265113479
# 	Total reward: 3344.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.15)
# Total gain: 160.94472651134586
# 	Total reward: 2988.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=250, delta=0.2)
# Total gain: -595.055273488654
# 	Total reward: 2232.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.001)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.003)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.004)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.005)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.006)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.007)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.01)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.03)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.05)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.1)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.15)
# Total gain: -935.0552734886528
# 	Total reward: 1892.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=500, delta=0.2)
# Total gain: -951.0552734886528
# 	Total reward: 1876.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.001)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.003)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.004)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.005)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.006)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.007)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.01)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
# PSLinUCB (alpha=0.01, omega=750, delta=0.03)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.05)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.1)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.15)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=750, delta=0.2)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.001)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.003)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.004)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.005)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.006)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.007)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.01)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.03)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.05)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.1)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.15)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1000, delta=0.2)
# Total gain: -1023.0552734886528
# 	Total reward: 1804.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.001)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.003)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.004)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.005)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.006)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.007)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.01)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.03)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.05)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.1)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.15)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=1500, delta=0.2)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.001)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.003)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.004)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.005)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.006)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.007)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.01)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.03)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.05)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.1)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.15)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.01, omega=2000, delta=0.2)
# Total gain: -1019.0552734886533
# 	Total reward: 1808.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.001)
# Total gain: 2356.9447265113463
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.003)
# Total gain: 2356.9447265113463
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.004)
# Total gain: 2356.9447265113463
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.005)
# Total gain: 2356.9447265113463
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.006)
# Total gain: 2356.9447265113463
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.007)
# Total gain: 2356.9447265113463
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.01)
# Total gain: 2356.9447265113463
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.03)
# Total gain: 2352.9447265113454
# 	Total reward: 5180.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.05)
# Total gain: 2340.9447265113454
# 	Total reward: 5168.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.1)
# Total gain: 1572.9447265113474
# 	Total reward: 4400.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.15)
# Total gain: -91.05527348865391
# 	Total reward: 2736.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=100, delta=0.2)
# Total gain: 1860.9447265113486
# 	Total reward: 4688.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.001)
# Total gain: 1764.9447265113479
# 	Total reward: 4592.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
# PSLinUCB (alpha=0.05, omega=150, delta=0.003)
# Total gain: 1764.9447265113479
# 	Total reward: 4592.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.004)
# Total gain: 1764.9447265113479
# 	Total reward: 4592.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.005)
# Total gain: 1764.9447265113479
# 	Total reward: 4592.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.006)
# Total gain: 1764.9447265113479
# 	Total reward: 4592.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.007)
# Total gain: 1764.9447265113479
# 	Total reward: 4592.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.01)
# Total gain: 1764.9447265113479
# 	Total reward: 4592.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.03)
# Total gain: 2116.944726511348
# 	Total reward: 4944.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.05)
# Total gain: 1504.9447265113474
# 	Total reward: 4332.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.1)
# Total gain: 2380.9447265113504
# 	Total reward: 5208.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.15)
# Total gain: 1088.9447265113465
# 	Total reward: 3916.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=150, delta=0.2)
# Total gain: 1516.9447265113477
# 	Total reward: 4344.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.001)
# Total gain: 1132.9447265113474
# 	Total reward: 3960.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.003)
# Total gain: 1132.9447265113474
# 	Total reward: 3960.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.004)
# Total gain: 1132.9447265113474
# 	Total reward: 3960.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.005)
# Total gain: 1132.9447265113474
# 	Total reward: 3960.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.006)
# Total gain: 1132.9447265113474
# 	Total reward: 3960.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.007)
# Total gain: 1132.9447265113474
# 	Total reward: 3960.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.01)
# Total gain: 1132.9447265113472
# 	Total reward: 3960.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.03)
# Total gain: 1076.944726511347
# 	Total reward: 3904.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.05)
# Total gain: 736.9447265113463
# 	Total reward: 3564.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.1)
# Total gain: 936.9447265113488
# 	Total reward: 3764.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.15)
# Total gain: 1500.9447265113477
# 	Total reward: 4328.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=250, delta=0.2)
# Total gain: 880.9447265113458
# 	Total reward: 3708.0
# 	Total cost: 2827.055273488652
# Execution time: 0.3s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.001)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.003)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.004)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.005)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.006)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.007)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.01)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.03)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.05)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.1)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.15)
# Total gain: 280.94472651134623
# 	Total reward: 3108.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=500, delta=0.2)
# Total gain: 144.94472651134598
# 	Total reward: 2972.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.001)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.003)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.004)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.005)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.006)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.007)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.01)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.03)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.05)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.1)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.15)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=750, delta=0.2)
# Total gain: 152.94472651134615
# 	Total reward: 2980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.001)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.003)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.004)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.005)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.006)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.007)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.01)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.03)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
# PSLinUCB (alpha=0.05, omega=1000, delta=0.05)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.1)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.15)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1000, delta=0.2)
# Total gain: -159.0552734886517
# 	Total reward: 2668.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.001)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.003)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.004)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.005)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.006)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.007)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.01)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.03)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.05)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.1)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.15)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=1500, delta=0.2)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.001)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.003)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.004)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.005)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.006)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.007)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.01)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.03)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.05)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.1)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.15)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.05, omega=2000, delta=0.2)
# Total gain: -1027.0552734886523
# 	Total reward: 1800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.001)
# Total gain: 880.9447265113473
# 	Total reward: 3708.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.003)
# Total gain: 880.9447265113473
# 	Total reward: 3708.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.004)
# Total gain: 880.9447265113473
# 	Total reward: 3708.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.005)
# Total gain: 880.9447265113473
# 	Total reward: 3708.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.006)
# Total gain: 880.9447265113473
# 	Total reward: 3708.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.007)
# Total gain: 880.9447265113473
# 	Total reward: 3708.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.01)
# Total gain: 880.9447265113473
# 	Total reward: 3708.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.03)
# Total gain: 1728.9447265113474
# 	Total reward: 4556.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.05)
# Total gain: 960.9447265113463
# 	Total reward: 3788.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.1)
# Total gain: 760.9447265113474
# 	Total reward: 3588.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.15)
# Total gain: 2100.944726511347
# 	Total reward: 4928.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=100, delta=0.2)
# Total gain: 1744.9447265113474
# 	Total reward: 4572.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.001)
# Total gain: 1672.9447265113474
# 	Total reward: 4500.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.003)
# Total gain: 1672.9447265113474
# 	Total reward: 4500.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.004)
# Total gain: 1672.9447265113474
# 	Total reward: 4500.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.005)
# Total gain: 1672.9447265113474
# 	Total reward: 4500.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.006)
# Total gain: 1672.9447265113474
# 	Total reward: 4500.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.007)
# Total gain: 1672.9447265113474
# 	Total reward: 4500.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.01)
# Total gain: 1672.9447265113474
# 	Total reward: 4500.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.03)
# Total gain: 1672.9447265113474
# 	Total reward: 4500.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.05)
# Total gain: 1672.9447265113474
# 	Total reward: 4500.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.1)
# Total gain: 1328.944726511347
# 	Total reward: 4156.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.15)
# Total gain: 1588.9447265113474
# 	Total reward: 4416.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=150, delta=0.2)
# Total gain: 1568.9447265113474
# 	Total reward: 4396.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.001)
# Total gain: 116.94472651134613
# 	Total reward: 2944.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.003)
# Total gain: 116.94472651134613
# 	Total reward: 2944.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.004)
# Total gain: 116.94472651134613
# 	Total reward: 2944.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.005)
# Total gain: 116.94472651134613
# 	Total reward: 2944.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
# PSLinUCB (alpha=0.1, omega=250, delta=0.006)
# Total gain: 1692.9447265113474
# 	Total reward: 4520.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.007)
# Total gain: 1692.9447265113474
# 	Total reward: 4520.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.01)
# Total gain: 1692.9447265113474
# 	Total reward: 4520.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.03)
# Total gain: 1712.9447265113474
# 	Total reward: 4540.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.05)
# Total gain: 1680.9447265113477
# 	Total reward: 4508.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.1)
# Total gain: 1460.9447265113479
# 	Total reward: 4288.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.15)
# Total gain: 1692.9447265113472
# 	Total reward: 4520.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=250, delta=0.2)
# Total gain: 1676.9447265113472
# 	Total reward: 4504.0
# 	Total cost: 2827.055273488652
# Execution time: 0.3s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.001)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.003)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.004)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.005)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.006)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.007)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.01)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.03)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.05)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.1)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.15)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=500, delta=0.2)
# Total gain: 1576.9447265113474
# 	Total reward: 4404.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.001)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.003)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.004)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.005)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.006)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.007)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.01)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.03)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.05)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.1)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.15)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=750, delta=0.2)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.001)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.003)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.004)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.005)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.006)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.007)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.01)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.03)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.05)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.1)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.15)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1000, delta=0.2)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.001)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.003)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.004)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.005)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.006)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.007)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.01)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.03)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.05)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.1)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=1500, delta=0.15)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
# PSLinUCB (alpha=0.1, omega=1500, delta=0.2)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.001)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.003)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.004)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.005)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.006)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.007)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.01)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.03)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.05)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.1)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.15)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.1, omega=2000, delta=0.2)
# Total gain: 1372.944726511348
# 	Total reward: 4200.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.001)
# Total gain: 2924.9447265113463
# 	Total reward: 5752.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.003)
# Total gain: 2924.9447265113463
# 	Total reward: 5752.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.004)
# Total gain: 2924.9447265113463
# 	Total reward: 5752.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.005)
# Total gain: 2924.9447265113463
# 	Total reward: 5752.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.006)
# Total gain: 2924.9447265113463
# 	Total reward: 5752.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.007)
# Total gain: 2924.9447265113463
# 	Total reward: 5752.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.01)
# Total gain: 3000.9447265113463
# 	Total reward: 5828.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.03)
# Total gain: 3152.944726511347
# 	Total reward: 5980.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.05)
# Total gain: 2996.9447265113463
# 	Total reward: 5824.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.1)
# Total gain: 2972.944726511347
# 	Total reward: 5800.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.15)
# Total gain: 1864.9447265113458
# 	Total reward: 4692.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=100, delta=0.2)
# Total gain: 3124.9447265113463
# 	Total reward: 5952.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.001)
# Total gain: 2548.944726511349
# 	Total reward: 5376.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.003)
# Total gain: 2548.944726511349
# 	Total reward: 5376.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.004)
# Total gain: 2548.944726511349
# 	Total reward: 5376.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.005)
# Total gain: 2548.944726511349
# 	Total reward: 5376.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.006)
# Total gain: 2548.944726511349
# 	Total reward: 5376.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.007)
# Total gain: 2548.944726511349
# 	Total reward: 5376.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.01)
# Total gain: 2548.944726511349
# 	Total reward: 5376.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.03)
# Total gain: 2548.944726511349
# 	Total reward: 5376.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.05)
# Total gain: 2556.94472651135
# 	Total reward: 5384.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.1)
# Total gain: 1556.9447265113463
# 	Total reward: 4384.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.15)
# Total gain: 1656.9447265113463
# 	Total reward: 4484.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=150, delta=0.2)
# Total gain: 2068.9447265113467
# 	Total reward: 4896.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=250, delta=0.001)
# Total gain: 1424.9447265113472
# 	Total reward: 4252.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=250, delta=0.003)
# Total gain: 1424.9447265113472
# 	Total reward: 4252.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=0.2, omega=250, delta=0.004)
# Total gain: 1424.9447265113472
# 	Total reward: 4252.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=250, delta=0.005)
# Total gain: 1424.9447265113472
# 	Total reward: 4252.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=250, delta=0.006)
# Total gain: 1424.9447265113472
# 	Total reward: 4252.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=0.2, omega=250, delta=0.007)
# ...
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=30.0, omega=2000, delta=0.005)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=30.0, omega=2000, delta=0.006)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=30.0, omega=2000, delta=0.007)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=30.0, omega=2000, delta=0.01)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=30.0, omega=2000, delta=0.03)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=30.0, omega=2000, delta=0.05)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=30.0, omega=2000, delta=0.1)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=30.0, omega=2000, delta=0.15)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=30.0, omega=2000, delta=0.2)
# Total gain: 2084.944726511347
# 	Total reward: 4912.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.001)
# Total gain: 2872.9447265113463
# 	Total reward: 5700.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.003)
# Total gain: 2872.9447265113463
# 	Total reward: 5700.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.004)
# Total gain: 2872.9447265113463
# 	Total reward: 5700.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.005)
# Total gain: 2872.9447265113463
# 	Total reward: 5700.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.006)
# Total gain: 2872.9447265113463
# 	Total reward: 5700.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.007)
# Total gain: 2872.9447265113463
# 	Total reward: 5700.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.01)
# Total gain: 2872.9447265113463
# 	Total reward: 5700.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.03)
# Total gain: 2848.9447265113463
# 	Total reward: 5676.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.05)
# Total gain: 2824.9447265113463
# 	Total reward: 5652.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.1)
# Total gain: 2808.9447265113463
# 	Total reward: 5636.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.15)
# Total gain: 2720.944726511347
# 	Total reward: 5548.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=100, delta=0.2)
# Total gain: 2872.9447265113463
# 	Total reward: 5700.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.001)
# Total gain: 2524.9447265113463
# 	Total reward: 5352.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.003)
# Total gain: 2524.9447265113463
# 	Total reward: 5352.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.004)
# Total gain: 2524.9447265113463
# 	Total reward: 5352.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.005)
# Total gain: 2524.9447265113463
# 	Total reward: 5352.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.006)
# Total gain: 2524.9447265113463
# 	Total reward: 5352.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.007)
# Total gain: 2524.9447265113463
# 	Total reward: 5352.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.01)
# Total gain: 2524.9447265113463
# 	Total reward: 5352.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.03)
# Total gain: 2524.9447265113463
# 	Total reward: 5352.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.05)
# Total gain: 2524.9447265113463
# 	Total reward: 5352.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.1)
# Total gain: 2544.9447265113463
# 	Total reward: 5372.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=150, delta=0.15)
# Total gain: 2508.9447265113463
# 	Total reward: 5336.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
# PSLinUCB (alpha=40.0, omega=150, delta=0.2)
# Total gain: 2492.9447265113463
# 	Total reward: 5320.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.001)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.003)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.004)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.005)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.006)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.007)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.01)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.03)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.05)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.1)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.15)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=250, delta=0.2)
# Total gain: 2356.944726511347
# 	Total reward: 5184.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.001)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.003)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.004)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.005)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.006)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.007)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.01)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.03)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.05)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.1)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.15)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=500, delta=0.2)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.001)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.003)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.004)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.005)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.006)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.007)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.01)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.03)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.05)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.1)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.15)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=750, delta=0.2)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.001)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.003)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.004)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.005)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.006)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.007)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.01)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.03)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.05)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.1)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.15)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1000, delta=0.2)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.001)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.003)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.004)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.005)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.006)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.007)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.01)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
# PSLinUCB (alpha=40.0, omega=1500, delta=0.03)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.05)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.1)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.15)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=1500, delta=0.2)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.001)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.003)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.004)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.005)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.006)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.007)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.01)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.03)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.05)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.1)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.15)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.2s
#
# PSLinUCB (alpha=40.0, omega=2000, delta=0.2)
# Total gain: 2112.9447265113504
# 	Total reward: 4940.0
# 	Total cost: 2827.055273488652
# Execution time: 0.1s

# %%
last_gains = {k:v[-1] for k,v in ps_linucb_gains.items()}
best_alpha_ps_linucb, best_omega_ps_linucb, best_delta_ps_linucb  = sorted(
    last_gains.items(), key=lambda x: x[1]
)[-1][0]

# %%
best_alpha_ps_linucb, best_omega_ps_linucb, best_delta_ps_linucb
# Out:
# (5.0, 100, 0.01)

# %%
del ps_linucb_gains

# %% [markdown]
# #### Evaluation

# %%
ps_linucb = algorithms.PSLinUCB(
    n_trials=NUM_OF_TRIALS,
    context_dimension=contexts.shape[1],
    n_arms=rewards.shape[1],
    alpha=best_alpha_ps_linucb,
    omega=best_omega_ps_linucb,
    delta=best_delta_ps_linucb,
)


gain_pslinucb = evaluation.evaluate_on_synthetic_data(
    ps_linucb,
    contexts,
    rewards,
    costs_vector,
    stop_after=NUM_OF_TRIALS,
)
change_points = ps_linucb.change_points
# Out:
# PSLinUCB (alpha=5.0, omega=100, delta=0.01)
# Total gain: 17737.463821340938
# 	Total reward: 30424.0
# 	Total cost: 12686.536178659138
# Execution time: 0.6s

# %% [markdown]
# ### SimOOS

# %% [markdown]
# #### Tuning

# %%
simoos_gains = {}

for beta in [0.1, 0.3, 0.5, 0.7, 1.0, 3.0, 5.0, 8.0]:
    for delta in [0.005, 0.01, 0.05, 0.1, 0.5, 0.8, 1.0, 5.0]:
        s = time.time()
        p_simoos = algorithms.SimOOSAlgorithm(
            all_contexts=contexts[:TUNING_NUM_TRIALS], 
            number_of_actions=rewards.shape[1],
            max_no_red_context=contexts.shape[1],
            beta_SimOOS=beta,
            delta_SimOOS=delta,
        )
        print(f"Took {time.time() - s} seconds")

        import warnings
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            s = time.time()
            gain_simoos = evaluation.evaluate_on_synthetic_data(
                p_simoos,
                contexts[:TUNING_NUM_TRIALS],
                rewards[:TUNING_NUM_TRIALS],
                costs_vector[:TUNING_NUM_TRIALS],
                stop_after=TUNING_NUM_TRIALS,
            )
            print(f"Took {time.time() - s} seconds")

        simoos_gains[(beta, delta)] = gain_simoos
# Out:
# Took 0.0008878707885742188 seconds
# Trial 0, time 2022-04-21 12:47:58.796595
# Trial 500, time 2022-04-21 12:48:15.678465
# Trial 1000, time 2022-04-21 12:48:24.489415
# Trial 1500, time 2022-04-21 12:48:29.055907
# Trial 2000, time 2022-04-21 12:48:30.998863
# SimOOS (beta=0.1, delta=0.005)
# Total gain: 6686.675610743825
# 	Total reward: 8976.0
# 	Total cost: 2289.324389256159
# Execution time: 32.5s
#
# Took 32.51989674568176 seconds
# Took 0.001264810562133789 seconds
# Trial 0, time 2022-04-21 12:48:31.317603
# Trial 500, time 2022-04-21 12:48:38.546107
# Trial 1000, time 2022-04-21 12:48:38.731228
# Trial 1500, time 2022-04-21 12:48:38.861593
# Trial 2000, time 2022-04-21 12:48:38.931128
# SimOOS (beta=0.1, delta=0.01)
# Total gain: 9202.61342412426
# 	Total reward: 9520.0
# 	Total cost: 317.3865758757409
# Execution time: 8.1s
#
# Took 8.07958197593689 seconds
# Took 0.0011279582977294922 seconds
# Trial 0, time 2022-04-21 12:48:39.398123
# Trial 500, time 2022-04-21 12:48:44.179319
# Trial 1000, time 2022-04-21 12:48:44.447983
# Trial 1500, time 2022-04-21 12:48:44.588626
# Trial 2000, time 2022-04-21 12:48:44.732067
# SimOOS (beta=0.1, delta=0.05)
# Total gain: 9658.659969687213
# 	Total reward: 10960.0
# 	Total cost: 1301.3400303127955
# Execution time: 5.4s
#
# Took 5.41649603843689 seconds
# Took 0.001135110855102539 seconds
# Trial 0, time 2022-04-21 12:48:44.815849
# Trial 500, time 2022-04-21 12:49:03.571794
# Trial 1000, time 2022-04-21 12:49:11.916790
# Trial 1500, time 2022-04-21 12:49:16.220890
# Trial 2000, time 2022-04-21 12:49:17.169602
# SimOOS (beta=0.1, delta=0.1)
# Total gain: 7710.560785880068
# 	Total reward: 9824.0
# 	Total cost: 2113.4392141199155
# Execution time: 32.6s
#
# Took 32.612725019454956 seconds
# Took 0.0012378692626953125 seconds
# Trial 0, time 2022-04-21 12:49:17.429988
# Trial 500, time 2022-04-21 12:49:18.757744
# Trial 1000, time 2022-04-21 12:49:18.881043
# Trial 1500, time 2022-04-21 12:49:19.004942
# Trial 2000, time 2022-04-21 12:49:19.072779
# SimOOS (beta=0.1, delta=0.5)
# Total gain: 9036.783549365056
# 	Total reward: 9056.0
# 	Total cost: 19.216450634943715
# Execution time: 1.8s
#
# Took 1.766303300857544 seconds
# Took 0.0009882450103759766 seconds
# Trial 0, time 2022-04-21 12:49:19.197257
# Trial 500, time 2022-04-21 12:49:23.923111
# Trial 1000, time 2022-04-21 12:49:24.106304
# Trial 1500, time 2022-04-21 12:49:24.459299
# Trial 1500, time 2022-04-21 12:57:26.305230
# Trial 2000, time 2022-04-21 12:57:27.392613
# SimOOS (beta=1.0, delta=0.8)
# Total gain: 9719.02579132204
# 	Total reward: 11360.0
# 	Total cost: 1640.9742086779677
# Execution time: 14.1s
#
# Took 14.052307844161987 seconds
# Took 0.0010268688201904297 seconds
# Trial 0, time 2022-04-21 12:57:27.928092
# Trial 500, time 2022-04-21 12:57:44.856806
# Trial 1000, time 2022-04-21 12:57:51.231185
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/performance_utils.py:37, in lazyprop.<locals>._lazyprop(self)
#      36 try:
# ---> 37     return getattr(self, attr_name)
#      38 except AttributeError:
#
# AttributeError: 'NegExpression' object has no attribute '_lazy_canonical_form'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/performance_utils.py:37, in lazyprop.<locals>._lazyprop(self)
#      36 try:
# ---> 37     return getattr(self, attr_name)
#      38 except AttributeError:
#
# AttributeError: 'AddExpression' object has no attribute '_lazy_canonical_form'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/performance_utils.py:37, in lazyprop.<locals>._lazyprop(self)
#      36 try:
# ---> 37     return getattr(self, attr_name)
#      38 except AttributeError:
#
# AttributeError: 'multiply' object has no attribute '_lazy_canonical_form'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [31], in <cell line: 3>()
#      17     warnings.simplefilter("ignore")
#      18     s = time.time()
# ---> 19     gain_simoos = evaluation.evaluate_on_synthetic_data(
#      20         p_simoos,
#      21         contexts[:TUNING_NUM_TRIALS],
#      22         rewards[:TUNING_NUM_TRIALS],
#      23         costs_vector[:TUNING_NUM_TRIALS],
#      24         stop_after=TUNING_NUM_TRIALS,
#      25     )
#      26     print(f"Took {time.time() - s} seconds")
#      28 simoos_gains[(beta, delta)] = gain_simoos
#
# File ~/git/work/examples/costly_nonstationary_bandits/evaluation.py:123, in evaluate_on_synthetic_data(bandit_algorithm, contexts, rewards, costs_vector, stop_after, num_repetitions, return_full)
#     121 paid_costs = np.zeros((num_repetitions, length))
#     122 for i in range(num_repetitions):
# --> 123     gain, reward, cost = evaluate_on_synthetic_data_once(bandit_algorithm, contexts, rewards, costs_vector, stop_after)
#     124     print()
#     125     gains[i, :] = np.array(gain)
#
# File ~/git/work/examples/costly_nonstationary_bandits/evaluation.py:200, in evaluate_on_synthetic_data_once(bandit_algorithm, contexts, rewards, costs_vector, stop_after)
#     197 context_at_t = contexts[trial]
#     198 cost_vector_at_t = costs_vector[trial]
# --> 200 features_to_observe = bandit_algorithm.choose_features_to_observe(
#     201     trial, feature_indices=list(range(num_features)), cost_vector=cost_vector_at_t,
#     202 )
#     203 observed_features = np.array(
#     204     [
#     205         feature if index in features_to_observe else None
#     206         for index, feature in enumerate(context_at_t)
#     207     ]
#     208 )
#     210 pool_indices = list(range(num_arms))
#
# File ~/git/work/examples/costly_nonstationary_bandits/algorithms/sim_oos.py:183, in SimOOSAlgorithm.choose_features_to_observe(self, t, feature_indices, cost_vector)
#     180 else:
#     181     # Optimistic Policy Optimization
#     182     if self.new_round == 1:
# --> 183         self.initialize_new_round(t, cost_vector)
#     184     self.observation_action_at_t = self.selected_observation_action_at_t
#     185 return [ind for ind, value in enumerate(self.observation_action_at_t) if value]
#
# File ~/git/work/examples/costly_nonstationary_bandits/algorithms/sim_oos.py:161, in SimOOSAlgorithm.initialize_new_round(self, t, cost_vector)
#     157 constraints = [cp.norm((prob_tilde - prob_hat), 1) <= confidence_interval_2, cp.sum(prob_tilde) == 1]
#     159 prob = cp.Problem(objective, constraints)
# --> 161 prob.solve()
#     163 # Similar to paper, set V_hat[i] = nu_t[i] as the maximizer
#     164 self.nu_t[i] = prob.value
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/problems/problem.py:473, in Problem.solve(self, *args, **kwargs)
#     471 else:
#     472     solve_func = Problem._solve
# --> 473 return solve_func(self, *args, **kwargs)
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/problems/problem.py:966, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, **kwargs)
#     963         self.unpack(chain.retrieve(soln))
#     964         return self.value
# --> 966 data, solving_chain, inverse_data = self.get_problem_data(
#     967     solver, gp, enforce_dpp, verbose)
#     969 if verbose:
#     970     print(_NUM_SOLVER_STR)
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/problems/problem.py:627, in Problem.get_problem_data(self, solver, gp, enforce_dpp, verbose)
#     624     s.LOGGER.info(
#     625              'Compiling problem (target solver=%s).', solver_name)
#     626     s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 627 data, inverse_data = solving_chain.apply(self, verbose)
#     628 safe_to_cache = (
#     629     isinstance(data, dict)
#     630     and s.PARAM_PROB in data
#     631     and not any(isinstance(reduction, EvalParams)
#     632                 for reduction in solving_chain.reductions)
#     633 )
#     634 self._compilation_time = time.time() - start
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/reductions/chain.py:76, in Chain.apply(self, problem, verbose)
#      74     if verbose:
#      75         s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76     problem, inv = r.apply(problem)
#      77     inverse_data.append(inv)
#      78 return problem, inverse_data
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/reductions/dcp2cone/cone_matrix_stuffing.py:311, in ConeMatrixStuffing.apply(self, problem)
#     309 # Form the constraints
#     310 extractor = CoeffExtractor(inverse_data)
# --> 311 params_to_objective, flattened_variable = self.stuffed_objective(
#     312     problem, extractor)
#     313 # Lower equality and inequality to Zero and NonNeg.
#     314 cons = []
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/reductions/dcp2cone/cone_matrix_stuffing.py:300, in ConeMatrixStuffing.stuffed_objective(self, problem, extractor)
#     298 def stuffed_objective(self, problem, extractor):
#     299     # Extract to c.T * x + r; c is represented by a ma
# --> 300     c = extractor.affine(problem.objective.expr)
#     302     boolean, integer = extract_mip_idx(problem.variables())
#     303     x = Variable(extractor.x_length, boolean=boolean, integer=integer)
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/coeff_extractor.py:82, in CoeffExtractor.affine(self, expr)
#      80 assert all([e.is_dpp() for e in expr_list])
#      81 num_rows = sum([e.size for e in expr_list])
# ---> 82 op_list = [e.canonical_form[0] for e in expr_list]
#      83 return canonInterface.get_problem_matrix(op_list,
#      84                                          self.x_length,
#      85                                          self.id_map,
#      86                                          self.param_to_size,
#      87                                          self.param_id_map,
#      88                                          num_rows)
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/coeff_extractor.py:82, in <listcomp>(.0)
#      80 assert all([e.is_dpp() for e in expr_list])
#      81 num_rows = sum([e.size for e in expr_list])
# ---> 82 op_list = [e.canonical_form[0] for e in expr_list]
#      83 return canonInterface.get_problem_matrix(op_list,
#      84                                          self.x_length,
#      85                                          self.id_map,
#      86                                          self.param_to_size,
#      87                                          self.param_id_map,
#      88                                          num_rows)
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/performance_utils.py:39, in lazyprop.<locals>._lazyprop(self)
#      37     return getattr(self, attr_name)
#      38 except AttributeError:
# ---> 39     setattr(self, attr_name, func(self))
#      40 return getattr(self, attr_name)
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/canonical.py:43, in Canonical.canonical_form(self)
#      36 @pu.lazyprop
#      37 def canonical_form(self):
#      38     """The graph implementation of the object stored as a property.
#      39
#      40     Returns:
#      41         A tuple of (affine expression, [constraints]).
#      42     """
# ---> 43     return self.canonicalize()
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/atoms/atom.py:322, in Atom.canonicalize(self)
#     320 constraints = []
#     321 for arg in self.args:
# --> 322     obj, constr = arg.canonical_form
#     323     arg_objs.append(obj)
#     324     constraints += constr
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/performance_utils.py:39, in lazyprop.<locals>._lazyprop(self)
#      37     return getattr(self, attr_name)
#      38 except AttributeError:
# ---> 39     setattr(self, attr_name, func(self))
#      40 return getattr(self, attr_name)
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/canonical.py:43, in Canonical.canonical_form(self)
#      36 @pu.lazyprop
#      37 def canonical_form(self):
#      38     """The graph implementation of the object stored as a property.
#      39
#      40     Returns:
#      41         A tuple of (affine expression, [constraints]).
#      42     """
# ---> 43     return self.canonicalize()
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/atoms/atom.py:322, in Atom.canonicalize(self)
#     320 constraints = []
#     321 for arg in self.args:
# --> 322     obj, constr = arg.canonical_form
#     323     arg_objs.append(obj)
#     324     constraints += constr
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/performance_utils.py:39, in lazyprop.<locals>._lazyprop(self)
#      37     return getattr(self, attr_name)
#      38 except AttributeError:
# ---> 39     setattr(self, attr_name, func(self))
#      40 return getattr(self, attr_name)
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/canonical.py:43, in Canonical.canonical_form(self)
#      36 @pu.lazyprop
#      37 def canonical_form(self):
#      38     """The graph implementation of the object stored as a property.
#      39
#      40     Returns:
#      41         A tuple of (affine expression, [constraints]).
#      42     """
# ---> 43     return self.canonicalize()
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/atoms/atom.py:322, in Atom.canonicalize(self)
#     320 constraints = []
#     321 for arg in self.args:
# --> 322     obj, constr = arg.canonical_form
#     323     arg_objs.append(obj)
#     324     constraints += constr
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/performance_utils.py:31, in lazyprop.<locals>._lazyprop(self)
#      28 @property
#      29 @functools.wraps(func)
#      30 def _lazyprop(self):
# ---> 31     if scopes.dpp_scope_active():
#      32         attr_name = '_lazy_dpp_' + func.__name__
#      33     else:
#
# File ~/miniforge3/envs/costly_nonstationary_bandits/lib/python3.10/site-packages/cvxpy/utilities/scopes.py:48, in dpp_scope_active()
#      44     yield
#      45     _dpp_scope_active = prev_state
# ---> 48 def dpp_scope_active() -> bool:
#      49     """Returns True if a `dpp_scope` is active. """
#      50     return _dpp_scope_active
#
# KeyboardInterrupt:

# %%
last_gains = {k:v[-1] for k,v in simoos_gains.items()}
best_beta_simoos, best_delta_simoos  = sorted(
    last_gains.items(), key=lambda x: x[1]
)[-1][0]

# %%
best_beta_simoos, best_delta_simoos

# %%
del simoos_gains

# %% [markdown]
# #### Evaluation

# %%
s = time.time()
p_simoos = algorithms.SimOOSAlgorithm(
    all_contexts=contexts, 
    number_of_actions=rewards.shape[1],
    max_no_red_context=contexts.shape[1],
    beta_SimOOS=best_beta_simoos,
    delta_SimOOS=best_delta_simoos,
)
print(f"Took {time.time() - s} seconds")

import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    s = time.time()
    gain_simoos = evaluation.evaluate_on_synthetic_data(
        p_simoos,
        contexts[:NUM_OF_TRIALS],
        rewards[:NUM_OF_TRIALS],
        costs_vector[:NUM_OF_TRIALS],
        stop_after=NUM_OF_TRIALS,
    )
    print(f"Took {time.time() - s} seconds")

# %% [markdown]
# ### Algorithm1

# %% [markdown]
# #### Tuning

# %%
# Tuning of algorithm1 is done separately in script, namely in /scripts/3_evaluate_alg1_on_synthetic.py

# %%
# alg1_gains = {}

# for beta in [1.0]:
#     for delta in  [0.1, 0.15]:
#         for window in [100, 500, 1000, 1250]:
#             s = time.time()
#             p_alg1 = algorithms.Algorithm1(
#                 all_contexts=contexts[:TUNING_NUM_TRIALS], 
#                 number_of_actions=rewards.shape[1],
#                 max_no_red_context=contexts.shape[1],
#                 beta=beta,
#                 delta=delta,
#                 window_length=window,
#             )
#             print(f"Took {time.time() - s} seconds")

#             import warnings
#             with warnings.catch_warnings():
#                 warnings.simplefilter("ignore")
#                 s = time.time()
#                 gain_alg1 = evaluation.evaluate_on_synthetic_data(
#                     p_alg1,
#                     contexts[:TUNING_NUM_TRIALS],
#                     rewards[:TUNING_NUM_TRIALS],
#                     costs_vector[:TUNING_NUM_TRIALS],
#                     stop_after=TUNING_NUM_TRIALS,
#                 )
#                 print(f"Took {time.time() - s} seconds")
#             alg1_gains[(beta, delta, window)] = gain_alg1

# %%
# last_gains = {k:v[-1] for k,v in alg1_gains.items()}
# best_beta_alg1, best_delta_alg1, best_window_alg1  = sorted(
#     last_gains.items(), key=lambda x: x[1]
# )[-1][0]

# %%
# sorted(
#     last_gains.items(), key=lambda x: x[1]
# )

# %%
# best_beta_alg1, best_delta_alg1, best_window_alg1

# %%
# del alg1_gains

# %% [markdown]
# #### Evaluation

# %%
# s = time.time()
# p_alg1 = algorithms.Algorithm1(
#     all_contexts=contexts, 
#     number_of_actions=rewards.shape[1],
#     max_no_red_context=contexts.shape[1],
#     beta=best_beta_alg1,
#     delta=best_delta_alg1,
#     window_length=best_window_alg1,
# )
# print(f"Took {time.time() - s} seconds")

# import warnings
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore")
#     s = time.time()
#     gain_alg1 = evaluation.evaluate_on_synthetic_data(
#         p_alg1,
#         contexts[:NUM_OF_TRIALS],
#         rewards[:NUM_OF_TRIALS],
#         costs_vector[:NUM_OF_TRIALS],
#         stop_after=NUM_OF_TRIALS,
#     )
#     print(f"Took {time.time() - s} seconds")

# %% [markdown]
# ### Plot cumulative gain

# %%
def plot_gains(gain_dict, change_points=()):
    fig, ax = plt.subplots(1,1, figsize=(16, 8));
        
    max_vline=0
    
    for label, gain in gain_dict.items():
        ax.plot(gain, label=label)
        max_vline=max(max_vline, max(gain))
    ax.set_xlabel('Trial')
    ax.set_ylabel('Cumulative gain')
    ax.set_title('Evaluation on synthetic data')
    
#     ax.vlines(change_points, 0, max_vline, label='change points', color='pink')

    plt.legend();
    plt.show();

# %%
plot_gains({
    'Random': gain_random,
    'E-greedy': gain_egreedy,
    'UCB1': gain_ucb,
    'LinUCB': gain_linucb,
    'PS-LinUCB': gain_pslinucb,
    'SimOOS': gain_simoos,
#     'Algorithm1': gain_alg1,
},
)
